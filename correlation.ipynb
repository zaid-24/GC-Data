# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('E:/GC_DATA/dataset/health.csv')
df.head(5)
# Out:
#    Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName DataSource  \
# 0  2021        AL   Alabama    Baldwin        1003    1003011300      BRFSS
# 1  2021        AL   Alabama   Chambers        1017    1017954000      BRFSS
# 2  2021        AL   Alabama   Cleburne        1029    1029959600      BRFSS
# 3  2021        AL   Alabama  Covington        1039    1039962000      BRFSS
# 4  2021        AL   Alabama    Fayette        1057    1057020400      BRFSS
#
#           Category                               Measure Data_Value_Unit  ...  \
# 0  Health Outcomes  Obesity among adults aged >=18 years               %  ...
# 1  Health Outcomes  Obesity among adults aged >=18 years               %  ...
# 2  Health Outcomes  Obesity among adults aged >=18 years               %  ...
# 3  Health Outcomes   Stroke among adults aged >=18 years               %  ...
# 4  Health Outcomes  Obesity among adults aged >=18 years               %  ...
#
# ...

# %%
df.describe()
# Out:
#                Year    CountyFIPS  LocationName    Data_Value  \
# count  2.555113e+06  2.555113e+06  2.555113e+06  2.555112e+06
# mean   2.020774e+03  2.856690e+04  2.856716e+10  2.835377e+01
# std    4.184108e-01  1.580379e+04  1.580379e+10  2.534658e+01
# min    2.020000e+03  1.001000e+03  1.001020e+09  3.000000e-01
# 25%    2.021000e+03  1.601100e+04  1.601194e+10  8.500000e+00
# 50%    2.021000e+03  2.910500e+04  2.910596e+10  1.850000e+01
# 75%    2.021000e+03  4.200300e+04  4.200348e+10  3.860000e+01
# max    2.021000e+03  5.604500e+04  5.604595e+10  9.790000e+01
#
#        Data_Value_Footnote_Symbol  Data_Value_Footnote  Low_Confidence_Limit  \
# count                         0.0                  0.0          2.555112e+06
# mean                          NaN                  NaN          2.586202e+01
# std                           NaN                  NaN          2.458749e+01
# min                           NaN                  NaN          2.000000e-01
# ...

# %%
# printing data value column
df['Data_Value'].head(5)
# Out:
# 0    35.1
# 1    46.3
# 2    39.2
# 3     4.2
# 4    36.0
# Name: Data_Value, dtype: float64

# %%
# printing df in scrollable format
pd.set_option('display.max_columns', 23)

# %%
df.head(10)
# Out:
#    Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName DataSource  \
# 0  2021        AL   Alabama    Baldwin        1003    1003011300      BRFSS
# 1  2021        AL   Alabama   Chambers        1017    1017954000      BRFSS
# 2  2021        AL   Alabama   Cleburne        1029    1029959600      BRFSS
# 3  2021        AL   Alabama  Covington        1039    1039962000      BRFSS
# 4  2021        AL   Alabama    Fayette        1057    1057020400      BRFSS
# 5  2021        AL   Alabama    Houston        1069    1069040301      BRFSS
# 6  2021        AL   Alabama  Jefferson        1073    1073002000      BRFSS
# 7  2021        AL   Alabama  Jefferson        1073    1073003600      BRFSS
# 8  2021        AL   Alabama  Jefferson        1073    1073003802      BRFSS
# 9  2021        AL   Alabama  Jefferson        1073    1073011205      BRFSS
#
#           Category                               Measure Data_Value_Unit  \
# ...

# %%
years_choose=[2002,2020]
# prining data for years 2002 and 2020 from df
df[df['YearStart'].isin(years_choose)].head(5)

# correlation between 2 dataframe columns
